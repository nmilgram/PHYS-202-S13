# %% [markdown]
# Example 1

# %%
f=lambda x: x**(0.5) + sin(x)

# %%
x=arange(0.,15.,0.001)

# %%
myplot= plot(x,f(x),lw=3)
ylabel('$x^{1/2} + \sin(x)$', fontsize=20)
show()

# %%
xmin=1.7
xmax=12.4

subx=x[logical_and((x>xmin),(x<xmax))]
ymax=max(f(subx))**1.05
ymin=0

myplot= plot(x,f(x),lw=3)

plot([xmin,xmin], [ymin,ymax], color='k', linestyle='--')
plot([xmax,xmax], [ymin,ymax], color='k', linestyle='--')
plot([xmin,xmax], [ymax,ymax], color='k', linestyle='--')

show()

# %%
N=1000

samples_x=xmin+(xmax-xmin)*random_sample(N);
samples_y=ymin+(ymax-ymin)*random_sample(N);

myplot= plot(x,f(x),lw=3)

plot (samples_x[1:200], samples_y[1:200], '.')

plot([xmin,xmin], [ymin,ymax], color='k', linestyle='--')
plot([xmax,xmax], [ymin,ymax], color='k', linestyle='--')
plot([xmin,xmax], [ymax,ymax], color='k', linestyle='--')

show()

# %%
newmask=(samples_y < f(samples_x))

# %%
sum(newmask)
# Out:
# 611

# %%
myplot= plot(x,f(x),lw=3)

plot (samples_x[1:200], samples_y[1:200], '.')

plot (samples_x[newmask[:200]], samples_y[newmask[:200]], 'r.')

plot([xmin,xmin], [ymin,ymax], color='k', linestyle='--')
plot([xmax,xmax], [ymin,ymax], color='k', linestyle='--')
plot([xmin,xmax], [ymax,ymax], color='k', linestyle='--')

show()

# %%
I=(xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 26.692272805

# %%
Iana=lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact=Iana(xmax)-Iana(xmin)
Ierr=100*(Iexact-I)/Iexact
print 'Iexact=',Iexact
print 'Ihitormiss=',I
print 'error=', abs(Ierr), '%'
# Out:
# Iexact= 26.5172145362
# Ihitormiss= 26.692272805
# error= 0.660168392037 %

# %% [markdown]
# Exercise 1

# %%
f=lambda x: x**(0.5) + sin(x)

x=arange(0.,15.,0.001)

xmin=1.7
xmax=12.4

subx=x[logical_and((x>xmin),(x<xmax))]
ymax=max(f(subx))**1.05
ymin=0

N=10000000 #I increased this value by incrementaly adding 0. This is the largest value that the kernel can handle, which gives a .005% error. .001% error is too small for this system.

samples_x=xmin+(xmax-xmin)*random_sample(N);
samples_y=ymin+(ymax-ymin)*random_sample(N);

newmask=(samples_y < f(samples_x))

newmask=(samples_y < f(samples_x))

myplot= plot(x,f(x),lw=3)

plot (samples_x[1:200], samples_y[1:200], '.')

plot (samples_x[newmask[:200]], samples_y[newmask[:200]], 'r.')

plot([xmin,xmin], [ymin,ymax], color='k', linestyle='--')
plot([xmax,xmax], [ymin,ymax], color='k', linestyle='--')
plot([xmin,xmax], [ymax,ymax], color='k', linestyle='--')

show()

I=(xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size

Iana=lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact=Iana(xmax)-Iana(xmin)
Ierr=100*(Iexact-I)/Iexact
print 'Iexact=',Iexact
print 'Ihitormiss=',I
print 'error=', abs(Ierr), '%'
# Out:
# Iexact= 26.5172145362
# Ihitormiss= 26.5185764438
# error= 0.00513593781999 %

# %% [markdown]
# Exercise 2

# %%
import numpy as np
f= lambda x: x**(0.5) +sin(x)
    
x=arange(0.,15.,0.001)
    
N=10000
xmin=1.7
xmax=12.4
xi=xmin+(xmax-xmin)*random_sample(N)
h=(xmax-xmin)/N
s=0.
for k in range (1,N+1):
    s+=f(xi)
a=np.mean(h*s)
print a
# Out:
# 26.6257062804

# %% [markdown]
# Example 2

# %%
fxyz=lambda x,y,z: sqrt(x**2 + y**2 + z**2)

N=1e6
L=1.; W=1.; H=1.
x=L*random_sample(N); y = W*random_sample(N); z=H*random_sample(N)

intMC = (L*W*H/N)*sum(fxyz(x,y,z))

# %%
print intMC
# Out:
# 0.960845102075
