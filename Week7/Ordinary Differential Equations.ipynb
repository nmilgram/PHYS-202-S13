# %%
g=9.8
l=.5
th0=20.*pi/180

t=arange(0., 10.01, .01)
theta_app = lambda t: th0*cos(sqrt(g/l)*t)

plot(t, theta_app(t))
show()

# %%
def deriv(theta_current,t):
    theta=theta_current[0]
    omega=theta_current[1]
    dtheta=omega
    domega=-(g/l)*sin(theta)
    return array([dtheta,domega])

# %%
from scipy.integrate import odeint

# %%
omega0=0
theta_init=array([th0,omega0])

theta=odeint(deriv,theta_init,t)

# %%
plot(t, theta_app(t), 'b-', t, theta[:,0], 'r--')

show()

# %%
th0=50.*pi/180
theta_init=array([th0,omega0])
theta=odeint(deriv,theta_init,t)
plot(t, theta_app(t), 'b-', t, theta[:,0], 'r--')

show()

# %%
th0=0
theta_init=array([th0,omega0])
theta=odeint(deriv,theta_init,t)
plot(t, theta[:,0], 'red')

th0=pi/4
theta_init=array([th0,omega0])
theta=odeint(deriv,theta_init,t)
plot(t, theta[:,0], 'blue')

th0=pi/2
theta_init=array([th0,omega0])
theta=odeint(deriv,theta_init,t)
plot(t, theta[:,0], 'green')

th0=3*pi/4
theta_init=array([th0,omega0])
theta=odeint(deriv,theta_init,t)
plot(t, theta[:,0], 'yellow')

th0=pi
theta_init=array([th0,omega0])
theta=odeint(deriv,theta_init,t)
plot(t, theta[:,0], 'purple')

# %%
th0=.95*pi
theta_init=array([th0,omega0])
theta=odeint(deriv,theta_init,t)

plot(t, theta[:,0])
plot(t, theta[:,1])

# %%
plot(theta[:,0], theta[:,1])

# %%
h=(l-cos(theta[:,0])*l)
Em=g*h+.5*l*(theta[:,1])**2

# %%
plot (t, Em)
