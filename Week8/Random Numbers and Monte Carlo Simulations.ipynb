# %%
import numpy.random
numpy.random?

# %%
print numpy.random.random(5)
print numpy.random.random(5)
# Out:
# [ 0.04653541  0.34241535  0.62163147  0.89017365  0.27036031]
# [ 0.6259255   0.4829978   0.80947833  0.00128006  0.94279671]

# %%
numpy.random.seed(4242)

# %%
print "using seed = 4242="
print numpy.random.random(5)
# Out:
# using seed = 4242=
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
numpy.random.seed(None)

# %%
print "using seed = none="
print numpy.random.random(5)
# Out:
# using seed = none=
# [ 0.98228941  0.47319779  0.98043778  0.46345394  0.24051289]

# %%
numpy.random.seed(None)
z=numpy.random.random(100000)
hist(z,100,normed=True)
plot([0.,1.],[1.,1.],'r-',lw=3)
xlabel('X',fontsize=20)
ylabel('sample probability',fontsize=20)
show()

# %%
x=arange(0.,pi+.01, .01)
f=lambda x: sin(x)/2.
F=lambda x:(cos(0)-cos(x))/2.
    
plot(x, f(x), label='True Distribution', lw=3)
plot(x, F(x), label='Cumulative Function', lw=3)
xlim(0,3.5)
ylim(0,1.1)
legend(loc=0)
show()

# %%
N=10000

z=numpy.random.random_sample(N);

Finv=lambda z: arccos(cos(0)-2*z)
    
xsamples=Finv(z);

hist(xsamples, 50, normed=True, label='Sampled Distribution')

plot(x, f(x), label='True Distribution', color='red',lw=3)
xlim(0,pi)
ylim(0,.7)
legend(loc=0)
show()

# %% [markdown]
# Exercise 1

# %% [markdown]
# $F(x)=-e^{-\lambda x}$

# %%
x=arange(0.,5.01, .01)
f=lambda x: e**(-x)
F=lambda x:-e**(-x)
    
plot(x, f(x), label='True Distribution', lw=3)
plot(x, F(x), label='Cumulative Function', lw=3)
xlim(0,5.)
ylim(-1.,1.)
legend(loc=0)
show()

# %%
N=10000

z=numpy.random.random_sample(N);

Finv=lambda z: -log(z)
    
xsamples=Finv(z);

hist(xsamples, 50, normed=True, label='Sampled Distribution')

plot(x, f(x), label='True Distribution', color='red',lw=3)

xlim(0,5.)
ylim(0,1.)
legend(loc=0)
show()

# %% [markdown]
# Excercise 2

# %%
x=arange(0.,5.01, .01)
f=lambda x: e**(-x)
F=cumsum(f(x))/sum(f(x))

plot(x, f(x), label='True Distribution', lw=3)
plot(x, F, label='Cumulative Sum', lw=3)
xlim(0,5.)
ylim(0.,1.)
legend(loc=0)
show()

# %%
N=10000

z=numpy.random.random_sample(N);

Index= F.searchsorted(z[:])

hist(x[Index],50, normed=True, label='Sampled Distribution')

#plot(x, f(x), label='True Distribution', color='red',lw=3)
#xlim(0,5.)
#ylim(0,1.)
legend(loc=0)
show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-216c4882844c> in <module>()
#       3 z=numpy.random.random_sample(N);
#       4
# ----> 5 Index= F.searchsorted(z[:])
#       6
#       7 hist(x[Index],50, normed=True, label='Sampled Distribution')
#
# NameError: name 'F' is not defined

# %%
def distribute1D(x,prob,N):
    
    f=prob
    
    F=cumsum(f(x))/sum(f(x))
    
    z=numpy.random.random_sample(N);

    Index= F.searchsorted(z)
    
    n,bins,patches = hist(x[Index],50, normed=True, label='Sampled Distribution')

    plot(x, f(x)*max(n), label='True Distribution', color='red',lw=3)
    #ylim(0,1)
    xlabel('x')
    ylabel('Probability')
    
    legend(loc=0)
    show()

# %%
distribute1D(arange(0.,5.01, .01),lambda x: e**(-x),10000)

# %%
distribute1D(arange(0.,5.01, .01),lambda x: x**2,10000)

# %%
distribute1D(arange(0.,5.01, .01),lambda x: x,100000)

# %% [markdown]
# Exercise 3

# %%
x=arange(-0.2,0.2,0.001)
P=lambda x:(sin(10e-6*pi*x/632.8e-9)/(10e-6*pi*x/632.8e-9))**2 * cos(2*pi*15e-6*x/632.8e-9)**2
myp = P(x)

# %%
distribute1D(x,P,10000)

# %%
distribute1D(x,P,1)

# %%
distribute1D(x,P,10)

# %%
distribute1D(x,P,100)

# %%
distribute1D(x,P,1000)

# %%
distribute1D(x,P,10000)

# %% [markdown]
# ^ Expected.
