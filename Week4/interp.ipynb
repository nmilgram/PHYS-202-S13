# %%
theta=arange(0.,2*pi+0.01, pi/10)
mask=(theta ==0.5)
print mask
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False]

# %%
newTheta = 0.5; newSin =0
from scipy.interpolate import interp1d
#help(interp1d)
sinInterp=interp1d(theta,sin(theta))
newSin=sinInterp(newTheta)
print newSin
# Out:
# 0.473922198704

# %%
plot(theta, sin(theta),newTheta, newSin, 'r+', markersize=20, markeredgewidth=3)
# Out:
# [<matplotlib.lines.Line2D at 0x10a451690>,
#  <matplotlib.lines.Line2D at 0x10a451b50>]

# %%
thetaNew=arange(0., 2*pi+0.1, pi/30)
sinNew = interp1d(theta, sin(theta))(thetaNew)
plot (theta, sin(theta), thetaNew, sinNew, 'r.')
# Out:
# [<matplotlib.lines.Line2D at 0x10a784110>,
#  <matplotlib.lines.Line2D at 0x10a7845d0>]

# %%
plot(thetaNew, sinNew - sin(thetaNew))
ylabel('difference between ....')
show()

# %%
sinNewC=interp1d(theta, sin(theta), kind='cubic')(thetaNew)
subplot(2,1,1)
plot(thetaNew, sinNew - sin(thetaNew), thetaNew, sinNewC - sin(thetaNew), 'r')
subplot(2,1,3)
plot(thetaNew, sinNewC-sin(thetaNew), 'r')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-b9a264685ff4> in <module>()
#       2 subplot(2,1,1)
#       3 plot(thetaNew, sinNew - sin(thetaNew), thetaNew, sinNewC - sin(thetaNew), 'r')
# ----> 4 subplot(2,1,3)
#       5 plot(thetaNew, sinNewC-sin(thetaNew), 'r')
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#     764
#     765     fig = gcf()
# --> 766     a = fig.add_subplot(*args, **kwargs)
#     767     bbox = a.bbox
#     768     byebye = []
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#     775                     # more similar to add_axes.
#     776
# --> 777             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#     778         self._axstack.add(key, a)
#     779         self.sca(a)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/axes.py in __init__(self, fig, *args, **kwargs)
#    8362                 self._subplotspec = GridSpec(rows, cols)[num[0]-1:num[1]]
#    8363             else:
# -> 8364                 self._subplotspec = GridSpec(rows, cols)[int(num)-1]
#    8365                 # num - 1 for converting from MATLAB to python indexing
#    8366         else:
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/gridspec.py in __getitem__(self, key)
#     173                     key += total
#     174                 if key >= total or key < 0 :
# --> 175                     raise IndexError("index out of range")
#     176                 num1, num2 = key, None
#     177
#
# IndexError: index out of range
