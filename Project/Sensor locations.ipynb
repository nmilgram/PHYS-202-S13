# %% [markdown]
# <table>
#   <thead>
#     <tr>
#       <th>Building</th>
#       <th>R</th>
#       <th>$\theta$</th>
#       <th>Z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Building 52</td>
#       <td>0m</td>
#       <td>$0^\circ$</td>
#       <td>107m</td>
#     </tr>
#     <tr>
#       <td>Building 53</td>
#       <td>186m</td>
#       <td>$79^\circ$</td>
#       <td>117m</td>
#     </tr>
#     <tr>
#       <td>Building 38</td>
#       <td>239m</td>
#       <td>$144^\circ$</td>
#       <td>102m</td>
#     </tr>
#     <tr>
#       <td>Building 35</td>
#       <td>342m</td>
#       <td>$108^\circ$</td>
#       <td>114m</td>
#     </tr>
#     <tr>
#       <td>Building 34</td>
#       <td>322m</td>
#       <td>$167^\circ$</td>
#       <td>105m</td>
#     </tr>
#     <tr>
#       <td>University Union</td>
#       <td>149m</td>
#       <td>$0^\circ$</td>
#       <td>118m</td>
#     </tr>
#     <tr>
#       <td>Sierra Madre</td>
#       <td>495m</td>
#       <td>$340^\circ$</td>
#       <td>133m</td>
#     </tr>
#     <tr>
#       <td>Building 26</td>
#       <td>188m</td>
#       <td>$218^\circ$</td>
#       <td>105m</td>
#     </tr>
#     <tr>
#       <td>Building 21</td>
#       <td>260m</td>
#       <td>$192^\circ$</td>
#       <td>100m</td>
#     </tr>
#     <tr>
#       <td>Performance Hall</td>
#       <td>216m</td>
#       <td>$316^\circ$</td>
#       <td>120m</td>
#     </tr>
#     <tr>
#       <td>Recreatin Center</td>
#       <td>207m</td>
#       <td>$243^\circ$</td>
#       <td>112m</td>
#     <tr>
#       <td>Santa Lucia</td>
#       <td>266m</td>
#       <td>$34^\circ$</td>
#       <td>124m</td>
#     </tr>
#     </tr>
#   </tbody>
# </table>
